# %%
import cv2

# %%
img = cv2.imread('Nashit.jpg')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,3))
plt.imshow(img)

# %%
img.shape
# Out:
# (388, 290, 3)

# %%
290//2
# Out:
# 145

# %%
388//2
# Out:
# 194

# %%
(h, w, c) = img.shape

# %%
h
# Out:
# 388

# %%
roi = img[130:160, 80:200]

# %%
plt.figure(figsize=(3,3))
plt.imshow(roi)

# %%
cv2.imshow('nashit', img)
cv2.waitKey()
# Out:
# -1

# %%
resize = cv2.resize(img, (500,500))

# %%
plt.imshow(resize)

# %%
(B,G,R) = img[100,200]

# %%
B
# Out:
# np.uint8(14)

# %%
G
# Out:
# np.uint8(12)

# %%
R
# Out:
# np.uint8(18)

# %%
rot = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE)

# %%
plt.imshow(rot)

# %%
(cX, cY) = (w//2, h//2)

# %%
cX
# Out:
# 145

# %%
cY
# Out:
# 194

# %%
matr = cv2.getRotationMatrix2D((cX, cY), 45, -1.0)

# %%
rot = cv2.warpAffine(img, matr, (w,h))

# %%
plt.imshow(rot)

# %%
flip =cv2.flip(img, 1)

# %%
plt.imshow(flip)

# %%
trans = cv2.transpose(img)
plt.imshow(trans)

# %%
line = cv2.line(img, (100, 100), (200, 200), (255,0,0), 1)
plt.imshow(line)

# %%
cir = cv2.circle(img, center=(200,150), radius= 50, color=(0,0,255), thickness= 3)
plt.imshow(cir)

# %%
text = cv2.putText(img, 'Nashit Humam', (50,50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), cv2.LINE_AA)

# %%
plt.imshow(text)

# %%
img1 =cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img1, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='gray')

# %%
img_inv = cv2.bitwise_not(gray)
plt.imshow(img_inv, cmap='gray')

# %%
img_g =cv2.GaussianBlur(img_inv, (25,25), sigmaX = 0, sigmaY = 0)
plt.imshow(img_g, cmap='gray')

# %%
img_p = cv2.divide(gray, 255-img_g, scale=255)
plt.imshow(img_p, cmap='gray')

# %%
# Out:
# < cv2.VideoCapture 000001FD4C67B270>

# %%
import cv2
cap = cv2.VideoCapture(0)
ret, frame =cap.read()
if ret:
    print(ret)
    cv2.imshow('Image', frame)
    cv2.waitKey()
cap.release()
# Out:
# True

# %%
frame
# Out:
# array([[[141, 145, 150],
#         [141, 145, 150],
#         [141, 145, 150],
#         ...,
#         [213, 196, 197],
#         [212, 194, 195],
#         [208, 190, 191]],
#
#        [[140, 144, 149],
#         [141, 145, 150],
#         [142, 146, 151],
#         ...,
#         [209, 193, 194],
#         [211, 194, 195],
#         [213, 195, 196]],
#
#        [[140, 144, 148],
#         [141, 145, 149],
#         [142, 146, 150],
#         ...,
#         [204, 189, 190],
#         [208, 192, 193],
#         [213, 196, 197]],
#
#        ...,
#
#        [[213, 225, 229],
#         [210, 222, 227],
#         [210, 222, 227],
#         ...,
#         [227, 238, 249],
#         [230, 240, 250],
#         [224, 234, 243]],
#
#        [[212, 223, 227],
#         [209, 220, 225],
#         [209, 219, 225],
#         ...,
#         [221, 229, 242],
#         [228, 236, 247],
#         [225, 233, 243]],
#
#        [[210, 221, 225],
#         [208, 219, 224],
#         [211, 221, 227],
#         ...,
#         [229, 236, 250],
#         [234, 240, 252],
#         [229, 235, 246]]], shape=(480, 640, 3), dtype=uint8)

# %%
img = cv2.imread('Nashit.jpg')

# %%
img[0,0] = [255,255,0]

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
